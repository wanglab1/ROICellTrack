# %%
#Visualize original ROI image
import cv2
import matplotlib.pyplot as plt
plt.imshow(cv2.cvtColor(cv2.imread("exampleROI.tiff"), cv2.COLOR_BGR2RGB))
plt.show()

# %%
from pipeline_step_A import extract_roi
import cv2
import matplotlib.pyplot as plt

#Function to crop ROI
extract_roi("exampleROI.tiff", "example_A1.tiff")
plt.imshow(cv2.cvtColor(cv2.imread("example_A1.tiff"), cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# Processed ROI saved to: example_A1.tiff

# %%
#Function to crop ROI and zoom in
from pipeline_step_A import crop_and_zoom
crop_and_zoom("exampleROI.tiff", "example_A1_zoom.tiff")
# Out:
# Zoomed ROI saved to: example_A1_zoom.tiff

# %%
plt.imshow(cv2.cvtColor(cv2.imread("example_A1_zoom.tiff"), cv2.COLOR_BGR2RGB))
plt.show()
